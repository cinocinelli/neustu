# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series

# %%
csv_input = 'movie_metadata.csv'

# %%
data=pd.read_csv(csv_input)[['movie_title','director_name','imdb_score']]

# %%
data.head()
# Out:
#                                          movie_title      director_name  \
# 0                                            Avatar       James Cameron
# 1          Pirates of the Caribbean: At World's End      Gore Verbinski
# 2                                           Spectre          Sam Mendes
# 3                             The Dark Knight Rises   Christopher Nolan
# 4  Star Wars: Episode VII - The Force Awakens    ...        Doug Walker
#
#    imdb_score
# 0         7.9
# 1         7.1
# 2         6.8
# 3         8.5
# 4         7.1

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5043, step=1)

# %%
data.columns
# Out:
# Index(['movie_title', 'director_name', 'imdb_score'], dtype='object')

# %%
data.columns = Series(['m_v','d_n','i_s'])

# %%
data.head()
# Out:
#                                                  m_v                d_n  i_s
# 0                                            Avatar       James Cameron  7.9
# 1          Pirates of the Caribbean: At World's End      Gore Verbinski  7.1
# 2                                           Spectre          Sam Mendes  6.8
# 3                             The Dark Knight Rises   Christopher Nolan  8.5
# 4  Star Wars: Episode VII - The Force Awakens    ...        Doug Walker  7.1

# %%
data.columns =data.columns.map(str.upper)

# %%
data.head()
# Out:
#                                                  M_V                D_N  I_S
# 0                                            Avatar       James Cameron  7.9
# 1          Pirates of the Caribbean: At World's End      Gore Verbinski  7.1
# 2                                           Spectre          Sam Mendes  6.8
# 3                             The Dark Knight Rises   Christopher Nolan  8.5
# 4  Star Wars: Episode VII - The Force Awakens    ...        Doug Walker  7.1

# %%
data=data.rename(columns=str.lower)

# %%
data.head()
# Out:
#                                                  m_v                d_n  i_s
# 0                                            Avatar       James Cameron  7.9
# 1          Pirates of the Caribbean: At World's End      Gore Verbinski  7.1
# 2                                           Spectre          Sam Mendes  6.8
# 3                             The Dark Knight Rises   Christopher Nolan  8.5
# 4  Star Wars: Episode VII - The Force Awakens    ...        Doug Walker  7.1

# %%
data = data.rename(columns={'m_v':'MV','d_n':'DN','i_s':'IS'})

# %%
data.head()
# Out:
#                                                   MV                 DN   IS
# 0                                            Avatar       James Cameron  7.9
# 1          Pirates of the Caribbean: At World's End      Gore Verbinski  7.1
# 2                                           Spectre          Sam Mendes  6.8
# 3                             The Dark Knight Rises   Christopher Nolan  8.5
# 4  Star Wars: Episode VII - The Force Awakens    ...        Doug Walker  7.1

# %%
def test_map(x):
    return x+'_ABC'

# %%
data.columns.map(test_map)
# Out:
# Index(['MV_ABC', 'DN_ABC', 'IS_ABC'], dtype='object')

# %%
data.head()
# Out:
#                                                   MV                 DN   IS
# 0                                            Avatar       James Cameron  7.9
# 1          Pirates of the Caribbean: At World's End      Gore Verbinski  7.1
# 2                                           Spectre          Sam Mendes  6.8
# 3                             The Dark Knight Rises   Christopher Nolan  8.5
# 4  Star Wars: Episode VII - The Force Awakens    ...        Doug Walker  7.1

# %%
data.rename(columns=test_map)
# Out:
#                                                  MV_ABC              DN_ABC  \
# 0                                               Avatar        James Cameron
# 1             Pirates of the Caribbean: At World's End       Gore Verbinski
# 2                                              Spectre           Sam Mendes
# 3                                The Dark Knight Rises    Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens    ...         Doug Walker
# 5                                          John Carter       Andrew Stanton
# 6                                         Spider-Man 3            Sam Raimi
# 7                                              Tangled         Nathan Greno
# 8                              Avengers: Age of Ultron          Joss Whedon
# 9               Harry Potter and the Half-Blood Prince          David Yates
# 10                  Batman v Superman: Dawn of Justice          Zack Snyder
# ...
