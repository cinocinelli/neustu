# %%
import pandas as pd

# %%
imdb=pd.read_csv('movie_metadata.csv')

# %%
imdb.head()#默认返回前五行
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
imdb.shape
# Out:
# (5043, 28)

# %%
imdb.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  \
# 5038                   637.0      NaN                  Comedy|Drama
# ...

# %%
sl=imdb['color']

# %%
imdb[['color','director_name','movie_title']].head()
# Out:
#    color      director_name                                        movie_title
# 0  Color      James Cameron                                            Avatar
# 1  Color     Gore Verbinski          Pirates of the Caribbean: At World's End
# 2  Color         Sam Mendes                                           Spectre
# 3  Color  Christopher Nolan                             The Dark Knight Rises
# 4    NaN        Doug Walker  Star Wars: Episode VII - The Force Awakens    ...

# %%
sub_df = imdb[['color','director_name','movie_title']]

# %%
sub_df.iloc[10:20,:]#iloc(内部位置)返回10到20行
# Out:
#     color     director_name                                   movie_title
# 10  Color       Zack Snyder           Batman v Superman: Dawn of Justice
# 11  Color      Bryan Singer                             Superman Returns
# 12  Color      Marc Forster                            Quantum of Solace
# 13  Color    Gore Verbinski   Pirates of the Caribbean: Dead Man's Chest
# 14  Color    Gore Verbinski                              The Lone Ranger
# 15  Color       Zack Snyder                                 Man of Steel
# 16  Color    Andrew Adamson     The Chronicles of Narnia: Prince Caspian
# 17  Color       Joss Whedon                                 The Avengers
# 18  Color      Rob Marshall  Pirates of the Caribbean: On Stranger Tides
# 19  Color  Barry Sonnenfeld                               Men in Black 3

# %%
sub_df.loc[15:17,:'movie_title']#闭区间，可以用标签
# Out:
#     color   director_name                                movie_title
# 15  Color     Zack Snyder                              Man of Steel
# 16  Color  Andrew Adamson  The Chronicles of Narnia: Prince Caspian
# 17  Color     Joss Whedon                              The Avengers

# %%
#reindex
sl = pd.Series([1,2,3,4],index=['a','b','c','d'])
sl
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
sl.reindex(index=['A','B','C','D','E'])
# Out:
# A   NaN
# B   NaN
# C   NaN
# D   NaN
# E   NaN
# dtype: float64

# %%
sl.reindex(index=['A','B','C','D','E'],fill_value=10)
# Out:
# A    10
# B    10
# C    10
# D    10
# E    10
# dtype: int64

# %%
s2=pd.Series(['A','B','C'],index=[1,5,10])
s2
# Out:
# 1     A
# 5     B
# 10    C
# dtype: object

# %%
s2.reindex(index=range(15))
# Out:
# 0     NaN
# 1       A
# 2     NaN
# 3     NaN
# 4     NaN
# 5       B
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10      C
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# dtype: object

# %%
s2.reindex(index=range(15),method='ffill')
# Out:
# 0     NaN
# 1       A
# 2       A
# 3       A
# 4       A
# 5       B
# 6       B
# 7       B
# 8       B
# 9       B
# 10      C
# 11      C
# 12      C
# 13      C
# 14      C
# dtype: object

# %%
import numpy as np

# %%
df1 = pd.DataFrame(np.random.rand(25).reshape(5,5),index= ['A','B','D','E','F'],columns=['c1','c2','c3','c4','c5'])

# %%
df1
# Out:
#          c1        c2        c3        c4        c5
# A  0.869825  0.225773  0.168353  0.247831  0.797882
# B  0.663711  0.241185  0.322614  0.040710  0.788861
# D  0.963566  0.685220  0.046824  0.566770  0.354685
# E  0.584715  0.853567  0.660984  0.228679  0.211271
# F  0.839803  0.931097  0.514447  0.886971  0.690580

# %%
df1.reindex(index=['A','B','C','D','E','F'])
# Out:
#          c1        c2        c3        c4        c5
# A  0.869825  0.225773  0.168353  0.247831  0.797882
# B  0.663711  0.241185  0.322614  0.040710  0.788861
# C       NaN       NaN       NaN       NaN       NaN
# D  0.963566  0.685220  0.046824  0.566770  0.354685
# E  0.584715  0.853567  0.660984  0.228679  0.211271
# F  0.839803  0.931097  0.514447  0.886971  0.690580

# %%
df1.reindex(columns=['c1','c2','c3','c4','c5','c6'])
# Out:
#          c1        c2        c3        c4        c5  c6
# A  0.869825  0.225773  0.168353  0.247831  0.797882 NaN
# B  0.663711  0.241185  0.322614  0.040710  0.788861 NaN
# D  0.963566  0.685220  0.046824  0.566770  0.354685 NaN
# E  0.584715  0.853567  0.660984  0.228679  0.211271 NaN
# F  0.839803  0.931097  0.514447  0.886971  0.690580 NaN

# %%
df1.reindex(columns=['c1','c2','c3','c4','c6'])
# Out:
#          c1        c2        c3        c4  c6
# A  0.869825  0.225773  0.168353  0.247831 NaN
# B  0.663711  0.241185  0.322614  0.040710 NaN
# D  0.963566  0.685220  0.046824  0.566770 NaN
# E  0.584715  0.853567  0.660984  0.228679 NaN
# F  0.839803  0.931097  0.514447  0.886971 NaN

# %%
df1.reindex(index=['A','B'])
# Out:
#          c1        c2        c3        c4        c5
# A  0.869825  0.225773  0.168353  0.247831  0.797882
# B  0.663711  0.241185  0.322614  0.040710  0.788861

# %%
#Drop
sl
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
sl.drop('a')
# Out:
# b    2
# c    3
# d    4
# dtype: int64

# %%
df1.drop('c2',axis=1)
# Out:
#          c1        c3        c4        c5
# A  0.869825  0.168353  0.247831  0.797882
# B  0.663711  0.322614  0.040710  0.788861
# D  0.963566  0.046824  0.566770  0.354685
# E  0.584715  0.660984  0.228679  0.211271
# F  0.839803  0.514447  0.886971  0.690580

# %%
df1
# Out:
#          c1        c2        c3        c4        c5
# A  0.869825  0.225773  0.168353  0.247831  0.797882
# B  0.663711  0.241185  0.322614  0.040710  0.788861
# D  0.963566  0.685220  0.046824  0.566770  0.354685
# E  0.584715  0.853567  0.660984  0.228679  0.211271
# F  0.839803  0.931097  0.514447  0.886971  0.690580
