# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series

# %%
from datetime import datetime

# %%
t1=datetime(2009,10,20)

# %%
t1
# Out:
# datetime.datetime(2009, 10, 20, 0, 0)

# %%
type(t1)
# Out:
# datetime.datetime

# %%
date_list=[datetime(2009,1,20),
           datetime(2009,2,20),
           datetime(2010,3,20),
           datetime(2009,2,10),
           datetime(2009,10,20)
          ]

# %%
date_list
# Out:
# [datetime.datetime(2009, 1, 20, 0, 0),
#  datetime.datetime(2009, 2, 20, 0, 0),
#  datetime.datetime(2010, 3, 20, 0, 0),
#  datetime.datetime(2009, 2, 10, 0, 0),
#  datetime.datetime(2009, 10, 20, 0, 0)]

# %%
s1 = Series(np.random.rand(5),index=date_list)

# %%
s1
# Out:
# 2009-01-20    0.507284
# 2009-02-20    0.467590
# 2010-03-20    0.023946
# 2009-02-10    0.357565
# 2009-10-20    0.953846
# dtype: float64

# %%
s1.index
# Out:
# DatetimeIndex(['2009-01-20', '2009-02-20', '2010-03-20', '2009-02-10',
#                '2009-10-20'],
#               dtype='datetime64[ns]', freq=None)

# %%
s1[1]
# Out:
# 0.46759011011821083

# %%
s1['2009-01-20']
# Out:
# 2009-01-20    0.507284
# dtype: float64

# %%
s1[datetime(2009,1,20)]
# Out:
# 0.5072841290706184

# %%
s1['20090120']
# Out:
# 2009-01-20    0.507284
# dtype: float64

# %%
s1['2009-02']
# Out:
# 2009-02-20    0.467590
# 2009-02-10    0.357565
# dtype: float64

# %%
s1['2009-2']
# Out:
# 2009-02-20    0.467590
# 2009-02-10    0.357565
# dtype: float64

# %%
#pd内部提供函数
pd.date_range(start='2009-01-01',periods=100)
# Out:
# DatetimeIndex(['2009-01-01', '2009-01-02', '2009-01-03', '2009-01-04',
#                '2009-01-05', '2009-01-06', '2009-01-07', '2009-01-08',
#                '2009-01-09', '2009-01-10', '2009-01-11', '2009-01-12',
#                '2009-01-13', '2009-01-14', '2009-01-15', '2009-01-16',
#                '2009-01-17', '2009-01-18', '2009-01-19', '2009-01-20',
#                '2009-01-21', '2009-01-22', '2009-01-23', '2009-01-24',
#                '2009-01-25', '2009-01-26', '2009-01-27', '2009-01-28',
#                '2009-01-29', '2009-01-30', '2009-01-31', '2009-02-01',
#                '2009-02-02', '2009-02-03', '2009-02-04', '2009-02-05',
#                '2009-02-06', '2009-02-07', '2009-02-08', '2009-02-09',
#                '2009-02-10', '2009-02-11', '2009-02-12', '2009-02-13',
#                '2009-02-14', '2009-02-15', '2009-02-16', '2009-02-17',
#                '2009-02-18', '2009-02-19', '2009-02-20', '2009-02-21',
# ...

# %%
pd.date_range(start='2009-01-01',periods=100,freq='W')
# Out:
# DatetimeIndex(['2009-01-04', '2009-01-11', '2009-01-18', '2009-01-25',
#                '2009-02-01', '2009-02-08', '2009-02-15', '2009-02-22',
#                '2009-03-01', '2009-03-08', '2009-03-15', '2009-03-22',
#                '2009-03-29', '2009-04-05', '2009-04-12', '2009-04-19',
#                '2009-04-26', '2009-05-03', '2009-05-10', '2009-05-17',
#                '2009-05-24', '2009-05-31', '2009-06-07', '2009-06-14',
#                '2009-06-21', '2009-06-28', '2009-07-05', '2009-07-12',
#                '2009-07-19', '2009-07-26', '2009-08-02', '2009-08-09',
#                '2009-08-16', '2009-08-23', '2009-08-30', '2009-09-06',
#                '2009-09-13', '2009-09-20', '2009-09-27', '2009-10-04',
#                '2009-10-11', '2009-10-18', '2009-10-25', '2009-11-01',
#                '2009-11-08', '2009-11-15', '2009-11-22', '2009-11-29',
#                '2009-12-06', '2009-12-13', '2009-12-20', '2009-12-27',
# ...

# %%
pd.date_range(start='2009-01-01',periods=100,freq='W-MON')
# Out:
# DatetimeIndex(['2009-01-05', '2009-01-12', '2009-01-19', '2009-01-26',
#                '2009-02-02', '2009-02-09', '2009-02-16', '2009-02-23',
#                '2009-03-02', '2009-03-09', '2009-03-16', '2009-03-23',
#                '2009-03-30', '2009-04-06', '2009-04-13', '2009-04-20',
#                '2009-04-27', '2009-05-04', '2009-05-11', '2009-05-18',
#                '2009-05-25', '2009-06-01', '2009-06-08', '2009-06-15',
#                '2009-06-22', '2009-06-29', '2009-07-06', '2009-07-13',
#                '2009-07-20', '2009-07-27', '2009-08-03', '2009-08-10',
#                '2009-08-17', '2009-08-24', '2009-08-31', '2009-09-07',
#                '2009-09-14', '2009-09-21', '2009-09-28', '2009-10-05',
#                '2009-10-12', '2009-10-19', '2009-10-26', '2009-11-02',
#                '2009-11-09', '2009-11-16', '2009-11-23', '2009-11-30',
#                '2009-12-07', '2009-12-14', '2009-12-21', '2009-12-28',
# ...

# %%
pd.date_range(start='2009-01-01',periods=100,freq='H')
# Out:
# DatetimeIndex(['2009-01-01 00:00:00', '2009-01-01 01:00:00',
#                '2009-01-01 02:00:00', '2009-01-01 03:00:00',
#                '2009-01-01 04:00:00', '2009-01-01 05:00:00',
#                '2009-01-01 06:00:00', '2009-01-01 07:00:00',
#                '2009-01-01 08:00:00', '2009-01-01 09:00:00',
#                '2009-01-01 10:00:00', '2009-01-01 11:00:00',
#                '2009-01-01 12:00:00', '2009-01-01 13:00:00',
#                '2009-01-01 14:00:00', '2009-01-01 15:00:00',
#                '2009-01-01 16:00:00', '2009-01-01 17:00:00',
#                '2009-01-01 18:00:00', '2009-01-01 19:00:00',
#                '2009-01-01 20:00:00', '2009-01-01 21:00:00',
#                '2009-01-01 22:00:00', '2009-01-01 23:00:00',
#                '2009-01-02 00:00:00', '2009-01-02 01:00:00',
#                '2009-01-02 02:00:00', '2009-01-02 03:00:00',
#                '2009-01-02 04:00:00', '2009-01-02 05:00:00',
# ...
